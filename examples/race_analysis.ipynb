# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('./dqn_log.csv')

# %%
def plot_log(df, attribute='position'):
    for idx in set(df['idx']):
        data = df[df['idx']==idx]
        data = data.reset_index()
        plt.plot (data.index, data[attribute])
        print max(data.index)

# %%
set(df['idx'])
# Out:
# {19422, 19423, 19424, 19425, 19426}

# %%
plot_log(df)
# Out:
# 103
# 104
# 107
# 103
# 110

# %%
df = pd.read_csv('./sarsa_log.csv')

# %%
plot_log(df)
# Out:
# 183
# 193
# 184
# 180
# 185

# %%
plot_log(df, attribute='gear')
# Out:
# 183
# 193
# 184
# 180
# 185

# %%
CIRCUIT = [[22, 7, 18, 10, 2, 6, 8, 6, 3, 18, 28, 7, 2, 7, 2, 13, 3, 11, 6, 6]*2,
           [1, 1, 1, 1, 3, 1, 1, 2, 2, 1]*2]

# %%
c= CIRCUIT[0]

# %%
changes = [sum(c[:idx+1]) for idx, e in enumerate(c)]

# %%
changes

# %%
set(df['health'])
